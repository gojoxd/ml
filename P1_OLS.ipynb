# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
sal_df=pd.read_csv(r"MBA Salary.csv")

# %%
sal_df.head()
# Out:
#    S. No.  Percentage in Grade 10  Salary
# 0       1                   62.00  270000
# 1       2                   76.33  200000
# 2       3                   72.00  240000
# 3       4                   60.00  250000
# 4       5                   61.00  180000

# %%
sal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   S. No.                  50 non-null     int64
#  1   Percentage in Grade 10  50 non-null     float64
#  2   Salary                  50 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 1.3 KB

# %%
sal_df.corr
print(sal_df.corr())
sns.heatmap(sal_df.corr());
# Out:
#                           S. No.  Percentage in Grade 10    Salary
# S. No.                  1.000000               -0.036681  0.018311
# Percentage in Grade 10 -0.036681                1.000000  0.395367
# Salary                  0.018311                0.395367  1.000000

# %%
x=sm.add_constant(sal_df['Percentage in Grade 10'])
y=sal_df['Salary']
print(x.shape)
print(y.shape)
x
# Out:
# (50, 2)
# (50,)
#     const  Percentage in Grade 10
# 0     1.0                   62.00
# 1     1.0                   76.33
# 2     1.0                   72.00
# 3     1.0                   60.00
# 4     1.0                   61.00
# 5     1.0                   55.00
# 6     1.0                   70.00
# 7     1.0                   68.00
# 8     1.0                   82.80
# 9     1.0                   59.00
# 10    1.0                   58.00
# 11    1.0                   60.00
# 12    1.0                   66.00
# 13    1.0                   83.00
# 14    1.0                   68.00
# 15    1.0                   37.33
# 16    1.0                   79.00
# 17    1.0                   68.40
# 18    1.0                   70.00
# 19    1.0                   59.00
# 20    1.0                   63.00
# 21    1.0                   50.00
# 22    1.0                   69.00
# 23    1.0                   52.00
# 24    1.0                   49.00
# 25    1.0                   64.60
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=100)

# %%
sal_fit=sm.OLS(y_train,x_train).fit()

# %%
print(sal_fit.summary2())
# Out:
#                           Results: Ordinary least squares
# ...
# Model:                    OLS                   Adj. R-squared:          0.190
# Dependent Variable:       Salary                AIC:                     1008.8680
# Date:                     2024-04-27 03:26      BIC:                     1012.2458
# No. Observations:         40                    Log-Likelihood:          -502.43
# Df Model:                 1                     F-statistic:             10.16
# Df Residuals:             38                    Prob (F-statistic):      0.00287
# R-squared:                0.211                 Scale:                   5.0121e+09
# -----------------------------------------------------------------------------------
#                          Coef.     Std.Err.    t    P>|t|     [0.025       0.975]
# -----------------------------------------------------------------------------------
# const                  30587.2857 71869.4497 0.4256 0.6728 -114904.8089 176079.3802
# ...

# %%
print(sal_fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.211
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     10.16
# Date:                Sat, 27 Apr 2024   Prob (F-statistic):            0.00287
# Time:                        03:26:55   Log-Likelihood:                -502.43
# No. Observations:                  40   AIC:                             1009.
# Df Residuals:                      38   BIC:                             1012.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   3.059e+04   7.19e+04      0.426      0.673   -1.15e+05    1.76e+05
# ...

# %%
sal_fit.params
# Out:
# const                     30587.285652
# Percentage in Grade 10     3560.587383
# dtype: float64

# %%
student_df=pd.read_csv(r"SLRD1.csv")
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Hours    25 non-null     float64
#  1   Scores   25 non-null     float64
# dtypes: float64(2)
# memory usage: 548.0 bytes

# %%
student_df.head()
student_df.dropna(inplace=True)

# %%
student_df.corr
print(student_df.corr())
sns.heatmap(student_df.corr());
# Out:
#            Hours    Scores
# Hours    1.000000  0.976191
# Scores   0.976191  1.000000

# %%
x=sm.add_constant(student_df['Scores '])
y=student_df['Hours ']
print(x.shape)
print(y.shape)
x
# Out:
# (25, 2)
# (25,)
#     const  Scores
# 0     1.0     21.0
# 1     1.0     47.0
# 2     1.0     27.0
# 3     1.0     75.0
# 4     1.0     30.0
# 5     1.0     20.0
# 6     1.0     88.0
# 7     1.0     60.0
# 8     1.0     81.0
# 9     1.0     25.0
# 10    1.0     85.0
# 11    1.0     62.0
# 12    1.0     41.0
# 13    1.0     42.0
# 14    1.0     17.0
# 15    1.0     95.0
# 16    1.0     30.0
# 17    1.0     24.0
# 18    1.0     67.0
# 19    1.0     69.0
# 20    1.0     30.0
# 21    1.0     54.0
# 22    1.0     35.0
# 23    1.0     76.0
# 24    1.0     86.0

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=100)
student_fit=sm.OLS(y_train,x_train).fit()

# %%
student_fit.params
# Out:
# const      0.067120
# Scores     0.096788
# dtype: float64

# %%
print(student_fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Hours    R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     356.7
# Date:                Sat, 27 Apr 2024   Prob (F-statistic):           2.59e-13
# Time:                        03:27:53   Log-Likelihood:                -16.512
# No. Observations:                  20   AIC:                             37.02
# Df Residuals:                      18   BIC:                             39.02
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0671      0.311      0.216      0.832      -0.587       0.721
# ...

# %%
print(student_fit.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.949
# Dependent Variable: Hours            AIC:                37.0245
# Date:               2024-04-27 03:27 BIC:                39.0159
# No. Observations:   20               Log-Likelihood:     -16.512
# Df Model:           1                F-statistic:        356.7
# Df Residuals:       18               Prob (F-statistic): 2.59e-13
# R-squared:          0.952            Scale:              0.33916
# -------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025   0.975]
# -------------------------------------------------------------------
# const       0.0671     0.3112    0.2157   0.8317   -0.5867   0.7209
# Scores      0.0968     0.0051   18.8855   0.0000    0.0860   0.1076
# -----------------------------------------------------------------
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
df=pd.read_csv(r"MLRD1.csv")

# %%
print(df.head())
print(df.info())
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Car     36 non-null     object
#  1   Model   36 non-null     object
#  2   Volume  36 non-null     int64
#  3   Weight  36 non-null     int64
#  4   CO2     36 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.5+ KB
# None

# %%
df.isna().sum()
# Out:
# Car       0
# Model     0
# Volume    0
# Weight    0
# CO2       0
# dtype: int64

# %%
df.drop('Car',axis=1,inplace=True)
df.drop('Model',axis=1,inplace=True)
df.corr()
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
x=sm.add_constant(df[['Weight', 'Volume']])
y=df['CO2']
print(x.shape)
print(y.shape)
x
# Out:
# (36, 3)
# (36,)
#     const  Weight  Volume
# 0     1.0     790    1000
# 1     1.0    1160    1200
# 2     1.0     929    1000
# 3     1.0     865     900
# 4     1.0    1140    1500
# 5     1.0     929    1000
# 6     1.0    1109    1400
# 7     1.0    1365    1500
# 8     1.0    1112    1500
# 9     1.0    1150    1600
# 10    1.0     980    1100
# 11    1.0     990    1300
# 12    1.0    1112    1000
# 13    1.0    1252    1600
# 14    1.0    1326    1600
# 15    1.0    1330    1600
# 16    1.0    1365    1600
# 17    1.0    1280    2200
# 18    1.0    1119    1600
# 19    1.0    1328    2000
# 20    1.0    1584    1600
# 21    1.0    1428    2000
# 22    1.0    1365    2100
# 23    1.0    1415    1600
# 24    1.0    1415    2000
# 25    1.0    1465    1500
# 26    1.0    1490    2000
# 27    1.0    1725    2000
# 28    1.0    1523    1600
# 29    1.0    1705    2000
# 30    1.0    1605    2100
# 31    1.0    1746    2000
# 32    1.0    1235    1600
# 33    1.0    1390    1600
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=100)
df_fit=sm.OLS(y_train,x_train).fit()

# %%
df_fit.params
# Out:
# const     79.285811
# Weight     0.014116
# Volume     0.002254
# dtype: float64

# %%
print(df_fit.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.293
# Dependent Variable: CO2              AIC:                180.8472
# Date:               2024-04-27 03:51 BIC:                184.8438
# No. Observations:   28               Log-Likelihood:     -87.424
# Df Model:           2                F-statistic:        6.583
# Df Residuals:       25               Prob (F-statistic): 0.00505
# R-squared:          0.345            Scale:              33.784
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     79.2858     6.1267   12.9410   0.0000   66.6676   91.9041
# Weight     0.0141     0.0074    1.9040   0.0685   -0.0012    0.0294
# Volume     0.0023     0.0050    0.4504   0.6563   -0.0081    0.0126
# ...

# %%
y_pred=df_fit.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.16363250973368615
